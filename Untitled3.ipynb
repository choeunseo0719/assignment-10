# %% [markdown]
# <a href="https://colab.research.google.com/github/choeunseo0719/assignment-10/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GRAPH 05
#
# print("""
# 인접 행렬을 사용한다.
#
# 이유:
# 모든 정점 사이에 간선이 존재하는 완전 그래프이므로
# 간선 수가 최대 O(V²)이다.
#
# 이 경우 인접 리스트의 공간 이점이 없으며,
# 인접 행렬은 간선 존재 여부를 O(1)에 확인할 수 있어
# 더 효율적이다.
# """)

# %% [markdown]
# # GRAPH 06
#
# print("""
# 인접 리스트를 사용한다.
#
# 이유:
# 희소 그래프는 간선 수가 적으므로
# 인접 행렬의 많은 공간이 낭비된다.
#
# 인접 리스트는 실제 존재하는 간선만 저장하므로
# 공간 효율이 높아 O(V+E)의 공간만 사용한다.
# """)

# %% [markdown]
# # GRAPH 08
#
# print("""
# DFS 순서
#
# 1 → 2 → 3 → 5 → 4 → 6
#
# DFS(1)에서 직접 호출되는 것은 DFS(2)뿐이다.
#
# 정답: 1번
# """)

# %% [markdown]
# # GRAPH 12
#
# print("""
# [Prim 알고리즘]
#
# 시작 정점: H(안)
#
# HE(4) 선택
# ED(2) 선택
# DC(1) 선택
# CF(3) 선택
# EG(5) 선택
# CB(9) 선택
# BA(8) 선택
#
# 최소 신장 트리
# HE, ED, DC, CF, EG, CB, BA
#
# 총 비용 = 4 + 2 + 1 + 3 + 5 + 9 + 8 = 32
#
#
# [Kruskal 알고리즘]
#
# CD(1) 선택
# DE(2) 선택
# CF(3) 선택
# EH(4) 선택
# EG(5) 선택
# GH(7) 제외 (사이클 발생)
# AB(8) 선택
# FG(8) 제외 (사이클 발생)
# FH(8) 제외 (사이클 발생)
# BC(9) 선택
#
# 최소 신장 트리
# CD, DE, CF, EH, EG, AB, BC
#
# 총 비용 = 1 + 2 + 3 + 4 + 5 + 8 + 9 = 32
# """)

# %% [markdown]
# # GRAPH 16
#
# print("""
# STACK을 사용한 위상 정렬 수도 코드
#
# topologicalSort(G):
#
#     각 정점의 진입차수를 계산한다.
#
#     stack을 만든다.
#
#     진입차수가 0인 정점을 push한다.
#
#     while stack이 비어있지 않으면
#
#         v = stack.pop()
#
#         v를 출력한다.
#
#         v와 연결된 정점 w에 대해
#
#             indegree[w] -= 1
#
#             indegree[w] == 0 이면
#
#                 stack.push(w)
#
# 가능한 위상 정렬 순서 개수
#
# 42가지
# """)

# %% [markdown]
# # GRAPH 17
#
# import pandas as pd
#
# df = pd.DataFrame({
#     "단계":[
#         "초기",
#         "{Q}",
#         "{Q,E}",
#         "{Q,E,C}",
#         "{Q,E,C,A}",
#         "{Q,E,C,A,F}",
#         "{Q,E,C,A,F,B}",
#         "{Q,E,C,A,F,B,G}",
#         "{Q,E,C,A,F,B,G,D}"
#     ],
#     "Q":[0,0,0,0,0,0,0,0,0],
#     "A":["∞",10,10,9,9,9,9,9,9],
#     "B":["∞","∞","∞",15,15,15,15,15,15],
#     "C":["∞",7,7,7,7,7,7,7,7],
#     "D":["∞","∞","∞","∞","∞",19,19,19,19],
#     "E":["∞",4,4,4,4,4,4,4,4],
#     "F":["∞","∞",12,12,12,12,12,12,12],
#     "G":["∞","∞",24,24,24,15,15,15,15]
# })
#
# display(df)
#
# print("""
# 최종 최단 거리
#
# Q = 0
# A = 9
# B = 15
# C = 7
# D = 19
# E = 4
# F = 12
# G = 15
# """)

# %% [markdown]
# # GRAPH 18
#
# print("""
# 정점
#
# A, B, C
#
# 간선
#
# A → B = 2
# A → C = 5
# C → B = -10
#
# A에서 시작하면
# B의 거리 2가 먼저 확정된다.
#
# 하지만 실제 최단 경로는
#
# A → C → B
#
# 거리 = 5 + (-10) = -5
#
# 따라서 음의 가중치가 존재하면
# 다익스트라 알고리즘은 올바르게 작동하지 않는다.
# """)

# %% [markdown]
# # GRAPH 22
#
# print("""
# 음의 사이클이 있는 경우
# """)

# %% [markdown]
# # SORTING 05
#
# print("""
# 초기 배열
#
# 12 70 30 20 55 25
#
#
# [선택 정렬]
#
# 12 25 30 20 55 70
#
# 12 25 30 20 55 70
#
# 12 25 20 30 55 70
#
# 12 20 25 30 55 70
#
# 12 20 25 30 55 70
#
#
# 최종 결과
#
# 12 20 25 30 55 70
#
#
# [버블 정렬]
#
# 12 30 20 55 25 70
#
# 12 20 30 25 55 70
#
# 12 20 25 30 55 70
#
# 12 20 25 30 55 70
#
#
# 최종 결과
#
# 12 20 25 30 55 70
#
#
# [삽입 정렬]
#
# 12 70 30 20 55 25
#
# 12 30 70 20 55 25
#
# 12 20 30 70 55 25
#
# 12 20 30 55 70 25
#
# 12 20 25 30 55 70
#
#
# 최종 결과
#
# 12 20 25 30 55 70
# """)

# %% [markdown]
# # SORTING 06
#
# print("""
# 초기 배열
#
# 12 70 30 20 55 25 40 50
#
#
# [병합 정렬]
#
# [12 70 30 20] [55 25 40 50]
#
# [12 70] [30 20] [55 25] [40 50]
#
# [12] [70] [30] [20] [55] [25] [40] [50]
#
# [12 70] [20 30] [25 55] [40 50]
#
# [12 20 30 70] [25 40 50 55]
#
# 12 20 25 30 40 50 55 70
#
#
# [힙 정렬]
#
# 70 55 40 50 12 25 30 20
#
# 55 50 40 20 12 25 30 70
#
# 50 30 40 20 12 25 55 70
#
# 40 30 25 20 12 50 55 70
#
# 30 20 25 12 40 50 55 70
#
# 25 20 12 30 40 50 55 70
#
# 20 12 25 30 40 50 55 70
#
# 12 20 25 30 40 50 55 70
#
#
# [퀵 정렬]
#
# pivot = 12
#
# 12 | 70 30 20 55 25 40 50
#
# pivot = 70
#
# 12 | 30 20 55 25 40 50 | 70
#
# pivot = 30
#
# 12 | 20 25 | 30 | 55 40 50 | 70
#
# pivot = 20
#
# 12 | 20 | 25 | 30 | 55 40 50 | 70
#
# pivot = 55
#
# 12 | 20 | 25 | 30 | 40 50 | 55 | 70
#
# pivot = 40
#
# 12 | 20 | 25 | 30 | 40 | 50 | 55 | 70
#
#
# 최종 결과
#
# 12 20 25 30 40 50 55 70
# """)
